# %% [markdown]
# <a href="https://colab.research.google.com/github/Saksham17P/C_dir/blob/main/PixelmonFullnFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random
import json
from gym import Env
from gym.spaces import Discrete, Box
import copy

# ===============================
# Environment with Pokémon Switching
# ===============================
class EnhancedPokemonBattleEnv(Env):
    def __init__(self, pokemon_data_path="/content/pokemon_trial.json", opponent_q_table=None):
        super(EnhancedPokemonBattleEnv, self).__init__()

        # Load Pokémon data (each with type and moves)
        self.pokemon_data = self.load_pokemon_data(pokemon_data_path)

        # Type effectiveness chart (customize as needed)
        self.type_chart = {
            "Fire": {"Grass": 2.0, "Water": 0.5, "Fire": 0.5},
            "Water": {"Fire": 2.0, "Grass": 0.5, "Water": 0.5},
            "Grass": {"Water": 2.0, "Fire": 0.5, "Grass": 0.5},
            "Electric": {"Water": 2.0, "Grass": 0.5, "Electric": 0.5},
            "Normal": {},
            "Dark": {"Psychic": 2.0, "Fighting": 0.5},
            "Dragon": {"Dragon": 2.0}
            # Add other types as needed.
        }

        # Action space: 0-3 use a move; 4-7 switch to bench slot (0-indexed)
        self.action_space = Discrete(8)
        # Observation: [agent_active_hp, opponent_active_hp, last_agent_damage, last_opponent_damage, agent_remaining]
        self.observation_space = Box(
            low=np.array([0, 0, 0, 0, 1]),
            high=np.array([500, 500, 100, 100, 4]),
            dtype=np.float32
        )

        self.max_steps = 300
        # For self-play: store the opponent's Q-table (if provided)
        self.opponent_q_table = opponent_q_table
        self.reset()

    def load_pokemon_data(self, path):
        with open(path, 'r') as f:
            return json.load(f)

    def get_type_multiplier(self, move_type, target_type):
        return self.type_chart.get(move_type, {}).get(target_type, 1.0)

    def select_random_moves(self, pokemon_name):
        all_moves = list(self.pokemon_data[pokemon_name]["moves"].values())
        if len(all_moves) <= 4:
            return all_moves
        return random.sample(all_moves, 4)

    def reset(self):
        self.steps = 0
        self.last_agent_damage = 0
        self.last_opponent_damage = 0
        self.last_move_type = None  # Track the last move type used by opponent

        # --- For the Agent ---
        self.agent_bench = []
        agent_keys = random.sample(list(self.pokemon_data.keys()), 4)
        for key in agent_keys:
            pkmn = {
                "name": key,
                "type": self.pokemon_data[key]["type"],
                "moves": self.select_random_moves(key),
                "hp": 500
            }
            self.agent_bench.append(pkmn)
        self.agent_active_idx = random.randint(0, 3)

        # --- For the Opponent ---
        self.opponent_bench = []
        opponent_keys = random.sample(list(self.pokemon_data.keys()), 4)
        for key in opponent_keys:
            pkmn = {
                "name": key,
                "type": self.pokemon_data[key]["type"],
                "moves": self.select_random_moves(key),
                "hp": 500
            }
            self.opponent_bench.append(pkmn)
        self.opponent_active_idx = random.randint(0, 3)

        return self._get_state()

    def _get_state(self):
        agent_remaining = sum(1 for p in self.agent_bench if p["hp"] > 0)
        return np.array([
            self.agent_bench[self.agent_active_idx]["hp"],
            self.opponent_bench[self.opponent_active_idx]["hp"],
            self.last_agent_damage,
            self.last_opponent_damage,
            agent_remaining
        ], dtype=np.float32)

    def _get_opponent_state(self):
        opponent_remaining = sum(1 for p in self.opponent_bench if p["hp"] > 0)
        return np.array([
            self.opponent_bench[self.opponent_active_idx]["hp"],
            self.agent_bench[self.agent_active_idx]["hp"],
            self.last_opponent_damage,
            self.last_agent_damage,
            opponent_remaining
        ], dtype=np.float32)

    def _get_opponent_action(self, state):
        if self.opponent_q_table is None:
            return self.action_space.sample()
        state_idx = discretize_state(state)
        return np.argmax(self.opponent_q_table[state_idx])

    def _find_best_type_matchup(self, move_type):
        best_resistance = 1.0
        best_idx = self.agent_active_idx
        for i, pokemon in enumerate(self.agent_bench):
            if pokemon["hp"] <= 0:
                continue
            resistance = self.get_type_multiplier(move_type, pokemon["type"])
            if resistance < best_resistance:
                best_resistance = resistance
                best_idx = i
        return best_idx

    def step(self, action):
        """
        Modified step method that accepts either a single integer (for single-agent training)
        or a tuple (agent_action, opponent_action) for adversarial testing.
        """
        # If action is a tuple, unpack it.
        if isinstance(action, tuple):
            agent_action, opponent_action = action
        else:
            agent_action = action
            opponent_action = None

        HIT_POINTS = 500.0
        self.steps += 1
        reward = 0
        self.last_agent_damage = 0
        self.last_opponent_damage = 0

        # Agent Turn: Check if agent's active Pokémon is fainted and force switch if needed.
        if self.agent_bench[self.agent_active_idx]["hp"] <= 0:
            available = [i for i, p in enumerate(self.agent_bench) if p["hp"] > 0]
            if available:
                self.agent_active_idx = random.choice(available)
            else:
                return self._get_state(), reward, True, {"info": "All agent Pokémon fainted"}

        # Optional: Use last opponent move type to decide switching
        if self.last_move_type and agent_action < 4:
            best_type_idx = self._find_best_type_matchup(self.last_move_type)
            if best_type_idx != self.agent_active_idx:
                agent_action = best_type_idx + 4
                reward += 0.1 / HIT_POINTS

        # Process Agent Action
        if agent_action >= 4:
            new_idx = agent_action - 4
            if self.agent_bench[new_idx]["hp"] <= 0:
                reward -= 0.5 / HIT_POINTS
            elif new_idx == self.agent_active_idx:
                reward -= 0.2 / HIT_POINTS
            else:
                self.agent_active_idx = new_idx
                reward -= 0.05 / HIT_POINTS
            agent_damage = 0
        else:
            active_agent = self.agent_bench[self.agent_active_idx]
            if active_agent["hp"] <= 0:
                agent_damage = 0
            else:
                move_idx = agent_action
                if move_idx >= len(active_agent["moves"]):
                    move_idx = 0
                move = active_agent["moves"][move_idx]
                base_damage = move["damage"]
                multiplier = self.get_type_multiplier(move["type"],
                                                      self.opponent_bench[self.opponent_active_idx]["type"])
                agent_damage = base_damage * multiplier
                self.opponent_bench[self.opponent_active_idx]["hp"] = max(
                    0, self.opponent_bench[self.opponent_active_idx]["hp"] - agent_damage
                )
        reward += agent_damage / HIT_POINTS
        self.last_agent_damage = agent_damage

        # Opponent Turn: Check if opponent's active Pokémon is fainted and force switch if needed.
        if self.opponent_bench[self.opponent_active_idx]["hp"] <= 0:
            available = [i for i, p in enumerate(self.opponent_bench) if p["hp"] > 0]
            if available:
                self.opponent_active_idx = random.choice(available)
            else:
                return self._get_state(), reward + 1, True, {"info": "All opponent Pokémon fainted"}

        # Process Opponent Action
        if opponent_action is None:
            if self.opponent_q_table is not None:
                opponent_state = self._get_opponent_state()
                opponent_action = self._get_opponent_action(opponent_state)
            else:
                opponent_action = random.choice(range(self.action_space.n))
        if opponent_action >= 4:
            new_idx = opponent_action - 4
            available = [i for i, p in enumerate(self.opponent_bench) if p["hp"] > 0]
            if available:
                if new_idx in available and new_idx != self.opponent_active_idx:
                    self.opponent_active_idx = new_idx
                else:
                    self.opponent_active_idx = random.choice(available)
            opponent_damage = 0
            self.last_move_type = None
        else:
            opp_active = self.opponent_bench[self.opponent_active_idx]
            if opp_active["hp"] <= 0:
                opponent_damage = 0
                self.last_move_type = None
            else:
                move_idx = opponent_action
                if move_idx >= len(opp_active["moves"]):
                    move_idx = 0
                opp_move = opp_active["moves"][move_idx]
                opp_base_damage = opp_move["damage"]
                opp_multiplier = self.get_type_multiplier(opp_move["type"],
                                                          self.agent_bench[self.agent_active_idx]["type"])
                opponent_damage = opp_base_damage * opp_multiplier
                self.agent_bench[self.agent_active_idx]["hp"] = max(
                    0, self.agent_bench[self.agent_active_idx]["hp"] - opponent_damage
                )
                self.last_move_type = opp_move["type"]
        self.last_opponent_damage = opponent_damage

        if self.opponent_bench[self.opponent_active_idx]["hp"] == 0:
            reward += 1

        done = (all(p["hp"] <= 0 for p in self.agent_bench) or
                all(p["hp"] <= 0 for p in self.opponent_bench) or
                self.steps >= self.max_steps)

        return self._get_state(), reward, done, {}

    def render(self, mode='human'):
        print(f"Step: {self.steps}")
        print(f"Agent Active: {self.agent_bench[self.agent_active_idx]['name']} [{self.agent_bench[self.agent_active_idx]['hp']:.1f} HP]")
        print(f"Opponent Active: {self.opponent_bench[self.opponent_active_idx]['name']} [{self.opponent_bench[self.opponent_active_idx]['hp']:.1f} HP]")
        if self.last_move_type:
            print(f"Last opponent move type: {self.last_move_type}")
        print("-" * 40)

# ===============================
# State Discretization Function (for Q-Learning)
# ===============================
def discretize_state(state):
    """
    State vector:
      [agent_active_hp, opponent_active_hp, last_agent_damage, last_opponent_damage, agent_remaining]
    """
    hp_bins = np.array([0, 100, 200, 300, 400, 500])
    damage_bins = np.array([0, 20, 40, 60, 80, 100])

    hp1_idx = np.digitize(state[0], hp_bins) - 1
    hp1_idx = min(hp1_idx, len(hp_bins) - 3)

    hp2_idx = np.digitize(state[1], hp_bins) - 1
    hp2_idx = min(hp2_idx, len(hp_bins) - 3)

    dmg1_idx = np.digitize(state[2], damage_bins) - 1
    dmg1_idx = min(dmg1_idx, len(damage_bins) - 3)

    dmg2_idx = np.digitize(state[3], damage_bins) - 1
    dmg2_idx = min(dmg2_idx, len(damage_bins) - 3)

    remain_idx = int(state[4]) - 1
    remain_idx = min(max(remain_idx, 0), 3)

    return (hp1_idx, hp2_idx, dmg1_idx, dmg2_idx, remain_idx)

# ===============================
# Minimax Q-Learning Implementation
# ===============================
hp_bins_count = 4
damage_bins_count = 4
remain_bins_count = 4

num_actions = 8  # 4 moves + 4 switching actions
epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.9997
alpha = 0.1
gamma = 0.95

q_table_agent = np.zeros((hp_bins_count, hp_bins_count, damage_bins_count, damage_bins_count, remain_bins_count, num_actions))
q_table_opponent = np.zeros((hp_bins_count, hp_bins_count, damage_bins_count, damage_bins_count, remain_bins_count, num_actions))

num_total_episodes = 30000
snapshot_interval = 5000
q_table_snapshots = []
snapshot_record = []

env = EnhancedPokemonBattleEnv("/content/pokemon_trial.json")
recent_rewards = []

def update_minimax_q(q_table, state_idx, action, reward, next_state_idx, alpha, gamma):
    old_value = q_table[state_idx][action]
    worst_case_value = np.min(q_table[next_state_idx])
    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * worst_case_value)
    q_table[state_idx][action] = new_value
    return q_table

for episode in range(num_total_episodes):
    if episode > 0 and episode % snapshot_interval == 0:
        snapshot = copy.deepcopy(q_table_agent)
        q_table_snapshots.append(snapshot)
        snapshot_record.append(episode)
        if len(q_table_snapshots) > 0:
            opponent_q_idx = random.randint(0, len(q_table_snapshots) - 1)
            env = EnhancedPokemonBattleEnv(
                "/content/pokemon_trial.json",
                opponent_q_table=q_table_snapshots[opponent_q_idx]
            )
            print(f"Self-play started: Agent playing against snapshot from episode {snapshot_record[opponent_q_idx]}")

    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        state_idx = discretize_state(state)
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q_table_agent[state_idx])
        next_state, reward, done, _ = env.step(action)
        next_state_idx = discretize_state(next_state)
        q_table_agent = update_minimax_q(q_table_agent, state_idx, action, reward, next_state_idx, alpha, gamma)

        opp_state_idx = (state_idx[1], state_idx[0], state_idx[3], state_idx[2], remain_bins_count - 1 - state_idx[4])
        opp_next_state_idx = (next_state_idx[1], next_state_idx[0], next_state_idx[3], next_state_idx[2], remain_bins_count - 1 - next_state_idx[4])
        if env.last_opponent_damage > 0 or env.last_move_type is not None:
            if env.last_opponent_damage > 0:
                opp_action = 0
            else:
                opp_action = 4
            q_table_opponent = update_minimax_q(q_table_opponent, opp_state_idx, opp_action, -reward, opp_next_state_idx, alpha, gamma)

        state = next_state
        total_reward += reward

    recent_rewards.append(total_reward)
    if len(recent_rewards) > 100:
        recent_rewards.pop(0)
    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    if (episode + 1) % 1000 == 0:
        avg_reward = np.mean(recent_rewards)
        print(f"Episode: {episode + 1}, Avg Reward: {avg_reward:.2f}, Epsilon: {epsilon:.3f}")

# ===============================
# Test the Agent Against Different Opponents
# ===============================
def test_against_opponent(agent_q_table, opponent_q_table=None, num_episodes=10):
    test_env = EnhancedPokemonBattleEnv("/content/pokemon_trial.json", opponent_q_table=opponent_q_table)
    wins = 0
    total_rewards = []
    for episode in range(num_episodes):
        state = test_env.reset()
        done = False
        total_reward = 0
        while not done:
            state_idx = discretize_state(state)
            action_values = q_table_agent[state_idx]
            action = np.argmax(action_values)
            state, reward, done, _ = test_env.step(action)
            total_reward += reward
        agent_has_living = any(p["hp"] > 0 for p in test_env.agent_bench)
        opp_all_fainted = all(p["hp"] <= 0 for p in test_env.opponent_bench)
        if agent_has_living and opp_all_fainted:
            wins += 1
        total_rewards.append(total_reward)
        print(f"Test Episode {episode + 1} finished with total reward: {total_reward:.2f}")
    return wins, total_rewards

print("\nTesting Minimax Q-Learning agent against random opponent:")
random_wins, random_rewards = test_against_opponent(q_table_agent, None)
print(f"Win rate against random opponent: {(random_wins/10)*100:.2f}%")
print(f"Average reward: {np.mean(random_rewards):.2f}")

for i, snapshot in enumerate(q_table_snapshots):
    print(f"\nTesting Minimax Q-Learning agent against snapshot {i+1} (from episode {snapshot_record[i]}):")
    snapshot_wins, snapshot_rewards = test_against_opponent(q_table_agent, snapshot)
    print(f"Win rate against snapshot {i+1}: {(snapshot_wins/10)*100:.2f}%")
    print(f"Average reward: {np.mean(snapshot_rewards):.2f}")

print("\nTesting Minimax Q-Learning agent against itself:")
self_wins, self_rewards = test_against_opponent(q_table_agent, q_table_agent)
print(f"Win rate against itself: {(self_wins/10)*100:.2f}%")
print(f"Average reward: {np.mean(self_rewards):.2f}")

# ===============================
# Define Max Damage Agent for Testing
# ===============================
class MaxDamageAgent:
    def __init__(self, env):
        self.env = env
        self.action_dim = env.action_space.n

    def select_action(self, state):
        # The max damage agent acts as the opponent.
        # It looks at its active Pokémon's moves and selects the move (0-3) that would cause the most damage
        # to the agent's active Pokémon.
        opp_active = self.env.opponent_bench[self.env.opponent_active_idx]
        agent_active = self.env.agent_bench[self.env.agent_active_idx]
        best_move = None
        best_damage = -float('inf')
        for i, move in enumerate(opp_active["moves"]):
            multiplier = self.env.get_type_multiplier(move["type"], agent_active["type"])
            damage = move["damage"] * multiplier
            if damage > best_damage:
                best_damage = damage
                best_move = i
        if best_move is None:
            best_move = random.randint(0, 3)
        return best_move, 0  # Dummy log probability

def test_against_max_damage_agent(agent_q_table, max_damage_agent, num_episodes=10):
    test_env = EnhancedPokemonBattleEnv("/content/pokemon_trial.json")
    wins = 0
    total_rewards = []
    for episode in range(num_episodes):
        state = test_env.reset()
        done = False
        total_reward = 0
        while not done:
            state_idx = discretize_state(state)
            agent_action = np.argmax(agent_q_table[state_idx])
            opp_action, _ = max_damage_agent.select_action(state)
            # Pass tuple of (agent_action, opponent_action)
            state, reward, done, _ = test_env.step((agent_action, opp_action))
            total_reward += reward
        agent_alive = any(p["hp"] > 0 for p in test_env.agent_bench)
        opp_all_fainted = all(p["hp"] <= 0 for p in test_env.opponent_bench)
        if agent_alive and opp_all_fainted:
            wins += 1
        total_rewards.append(total_reward)
        print(f"Max Damage Test Episode {episode + 1} finished with total reward: {total_reward:.2f}")
    return wins, total_rewards

max_damage_agent = MaxDamageAgent(env)
print("\nTesting Minimax Q-Learning agent against Max Damage Agent:")
max_wins, max_rewards = test_against_max_damage_agent(q_table_agent, max_damage_agent, num_episodes=10)
print(f"Win rate against max damage agent: {(max_wins/10)*100:.2f}%")
print(f"Average reward: {np.mean(max_rewards):.2f}")

# ===============================
# Analyze the learned strategy
# ===============================
def analyze_strategy(q_table):
    print("\nStrategy Analysis:")
    low_agent_hp_high_opp_hp = (0, 3, 0, 0, 3)
    action = np.argmax(q_table[low_agent_hp_high_opp_hp])
    print(f"When agent HP is low but opponent HP is high: {'Use move' if action < 4 else 'Switch Pokemon'} (Action {action})")
    both_low_hp = (0, 0, 0, 0, 3)
    action = np.argmax(q_table[both_low_hp])
    print(f"When both have low HP: {'Use move' if action < 4 else 'Switch Pokemon'} (Action {action})")
    type_advantage = (2, 2, 3, 0, 3)
    action = np.argmax(q_table[type_advantage])
    print(f"When agent has type advantage (high damage): {'Use move' if action < 4 else 'Switch Pokemon'} (Action {action})")

analyze_strategy(q_table_agent)
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Episode: 1000, Avg Reward: 4.72, Epsilon: 0.741
# Episode: 2000, Avg Reward: 5.23, Epsilon: 0.549
# Episode: 3000, Avg Reward: 5.30, Epsilon: 0.407
# Episode: 4000, Avg Reward: 5.36, Epsilon: 0.301
# Episode: 5000, Avg Reward: 5.28, Epsilon: 0.223
# Self-play started: Agent playing against snapshot from episode 5000
# Episode: 6000, Avg Reward: 4.06, Epsilon: 0.165
# Episode: 7000, Avg Reward: 4.18, Epsilon: 0.122
# Episode: 8000, Avg Reward: 4.47, Epsilon: 0.091
# Episode: 9000, Avg Reward: 4.56, Epsilon: 0.067
# Episode: 10000, Avg Reward: 4.33, Epsilon: 0.050
# Self-play started: Agent playing against snapshot from episode 10000
# Episode: 11000, Avg Reward: 4.33, Epsilon: 0.050
# Episode: 12000, Avg Reward: 4.54, Epsilon: 0.050
# Episode: 13000, Avg Reward: 4.36, Epsilon: 0.050
# Episode: 14000, Avg Reward: 4.44, Epsilon: 0.050
# Episode: 15000, Avg Reward: 4.42, Epsilon: 0.050
# Self-play started: Agent playing against snapshot from episode 5000
# Episode: 16000, Avg Reward: 4.65, Epsilon: 0.050
# Episode: 17000, Avg Reward: 4.44, Epsilon: 0.050
# Episode: 18000, Avg Reward: 4.43, Epsilon: 0.050
# Episode: 19000, Avg Reward: 4.46, Epsilon: 0.050
# Episode: 20000, Avg Reward: 4.52, Epsilon: 0.050
# Self-play started: Agent playing against snapshot from episode 10000
# Episode: 21000, Avg Reward: 4.52, Epsilon: 0.050
# Episode: 22000, Avg Reward: 4.52, Epsilon: 0.050
# Episode: 23000, Avg Reward: 4.56, Epsilon: 0.050
# Episode: 24000, Avg Reward: 4.45, Epsilon: 0.050
# Episode: 25000, Avg Reward: 4.64, Epsilon: 0.050
# Self-play started: Agent playing against snapshot from episode 20000
# Episode: 26000, Avg Reward: 4.52, Epsilon: 0.050
# Episode: 27000, Avg Reward: 4.30, Epsilon: 0.050
# Episode: 28000, Avg Reward: 4.39, Epsilon: 0.050
# Episode: 29000, Avg Reward: 4.44, Epsilon: 0.050
# Episode: 30000, Avg Reward: 4.54, Epsilon: 0.050
#
# Testing Minimax Q-Learning agent against random opponent:
# Test Episode 1 finished with total reward: 5.14
# Test Episode 2 finished with total reward: 5.33
# Test Episode 3 finished with total reward: 6.11
# Test Episode 4 finished with total reward: 5.60
# Test Episode 5 finished with total reward: 5.21
# Test Episode 6 finished with total reward: 5.35
# Test Episode 7 finished with total reward: 5.52
# Test Episode 8 finished with total reward: 5.21
# Test Episode 9 finished with total reward: 5.64
# Test Episode 10 finished with total reward: 5.52
# Win rate against random opponent: 100.00%
# Average reward: 5.46
#
# Testing Minimax Q-Learning agent against snapshot 1 (from episode 5000):
# Test Episode 1 finished with total reward: 4.04
# Test Episode 2 finished with total reward: 5.22
# Test Episode 3 finished with total reward: 5.32
# Test Episode 4 finished with total reward: 4.03
# Test Episode 5 finished with total reward: 5.37
# Test Episode 6 finished with total reward: 5.60
# Test Episode 7 finished with total reward: 3.56
# Test Episode 8 finished with total reward: 3.50
# Test Episode 9 finished with total reward: 3.07
# Test Episode 10 finished with total reward: 5.56
# Win rate against snapshot 1: 50.00%
# Average reward: 4.53
#
# Testing Minimax Q-Learning agent against snapshot 2 (from episode 10000):
# Test Episode 1 finished with total reward: 5.50
# Test Episode 2 finished with total reward: 3.28
# Test Episode 3 finished with total reward: 5.58
# Test Episode 4 finished with total reward: 2.97
# Test Episode 5 finished with total reward: 3.70
# Test Episode 6 finished with total reward: 5.30
# Test Episode 7 finished with total reward: 4.22
# Test Episode 8 finished with total reward: 5.25
# Test Episode 9 finished with total reward: 5.37
# Test Episode 10 finished with total reward: 4.02
# Win rate against snapshot 2: 50.00%
# Average reward: 4.52
#
# Testing Minimax Q-Learning agent against snapshot 3 (from episode 15000):
# Test Episode 1 finished with total reward: 5.33
# Test Episode 2 finished with total reward: 3.23
# Test Episode 3 finished with total reward: 2.98
# Test Episode 4 finished with total reward: 3.83
# Test Episode 5 finished with total reward: 4.30
# Test Episode 6 finished with total reward: 3.46
# Test Episode 7 finished with total reward: 5.15
# Test Episode 8 finished with total reward: 4.42
# Test Episode 9 finished with total reward: 5.31
# Test Episode 10 finished with total reward: 3.49
# Win rate against snapshot 3: 30.00%
# Average reward: 4.15
#
# Testing Minimax Q-Learning agent against snapshot 4 (from episode 20000):
# Test Episode 1 finished with total reward: 5.53
# Test Episode 2 finished with total reward: 5.75
# Test Episode 3 finished with total reward: 3.84
# Test Episode 4 finished with total reward: 5.90
# Test Episode 5 finished with total reward: 5.41
# Test Episode 6 finished with total reward: 4.14
# Test Episode 7 finished with total reward: 5.18
# Test Episode 8 finished with total reward: 5.52
# Test Episode 9 finished with total reward: 3.15
# Test Episode 10 finished with total reward: 3.43
# Win rate against snapshot 4: 60.00%
# Average reward: 4.78
#
# Testing Minimax Q-Learning agent against snapshot 5 (from episode 25000):
# Test Episode 1 finished with total reward: 5.20
# Test Episode 2 finished with total reward: 5.52
# Test Episode 3 finished with total reward: 5.10
# Test Episode 4 finished with total reward: 3.17
# Test Episode 5 finished with total reward: 5.15
# Test Episode 6 finished with total reward: 3.20
# Test Episode 7 finished with total reward: 5.07
# Test Episode 8 finished with total reward: 3.65
# Test Episode 9 finished with total reward: 5.54
# Test Episode 10 finished with total reward: 5.14
# Win rate against snapshot 5: 70.00%
# Average reward: 4.67
#
# Testing Minimax Q-Learning agent against itself:
# Test Episode 1 finished with total reward: 3.84
# Test Episode 2 finished with total reward: 5.20
# Test Episode 3 finished with total reward: 5.30
# Test Episode 4 finished with total reward: 4.03
# Test Episode 5 finished with total reward: 5.27
# Test Episode 6 finished with total reward: 5.55
# Test Episode 7 finished with total reward: 5.50
# Test Episode 8 finished with total reward: 5.32
# Test Episode 9 finished with total reward: 5.86
# Test Episode 10 finished with total reward: 5.35
# Win rate against itself: 80.00%
# Average reward: 5.12
#
# Testing Minimax Q-Learning agent against Max Damage Agent:
# Max Damage Test Episode 1 finished with total reward: 5.39
# Max Damage Test Episode 2 finished with total reward: 3.88
# Max Damage Test Episode 3 finished with total reward: 5.13
# Max Damage Test Episode 4 finished with total reward: 3.44
# Max Damage Test Episode 5 finished with total reward: 4.18
# Max Damage Test Episode 6 finished with total reward: 5.22
# Max Damage Test Episode 7 finished with total reward: 3.46
# Max Damage Test Episode 8 finished with total reward: 3.18
# Max Damage Test Episode 9 finished with total reward: 5.34
# Max Damage Test Episode 10 finished with total reward: 3.05
# Win rate against max damage agent: 40.00%
# Average reward: 4.23
#
# Strategy Analysis:
# When agent HP is low but opponent HP is high: Use move (Action 3)
# When both have low HP: Use move (Action 3)
# When agent has type advantage (high damage): Use move (Action 3)

# %%
def test_against_max_damage_agent(agent_q_table, max_damage_agent, num_episodes=1000):
    test_env = EnhancedPokemonBattleEnv("/content/pokemon_trial.json")
    wins = 0
    total_rewards = []
    for episode in range(num_episodes):
        state = test_env.reset()
        done = False
        total_reward = 0
        while not done:
            state_idx = discretize_state(state)
            agent_action = np.argmax(agent_q_table[state_idx])
            opp_action, _ = max_damage_agent.select_action(state)
            state, reward, done, _ = test_env.step((agent_action, opp_action))
            total_reward += reward
        agent_alive = any(p["hp"] > 0 for p in test_env.agent_bench)
        opp_all_fainted = all(p["hp"] <= 0 for p in test_env.opponent_bench)
        if agent_alive and opp_all_fainted:
            wins += 1
        total_rewards.append(total_reward)
        print(f"Max Damage Test Episode {episode + 1} finished with total reward: {total_reward:.2f}")
    return wins, total_rewards

max_damage_agent = MaxDamageAgent(env)
print("\nTesting Minimax Q-Learning agent against Max Damage Agent:")
max_wins, max_rewards = test_against_max_damage_agent(q_table_agent, max_damage_agent, num_episodes=1000)
print(f"Win rate against max damage agent: {(max_wins/1000)*100:.2f}%")
print(f"Average reward: {np.mean(max_rewards):.2f}")
# Out:
# Testing Minimax Q-Learning agent against Max Damage Agent:
# Max Damage Test Episode 1 finished with total reward: 3.41
# Max Damage Test Episode 2 finished with total reward: 5.45
# Max Damage Test Episode 3 finished with total reward: 3.04
# Max Damage Test Episode 4 finished with total reward: 5.92
# Max Damage Test Episode 5 finished with total reward: 5.28
# Max Damage Test Episode 6 finished with total reward: 3.49
# Max Damage Test Episode 7 finished with total reward: 3.40
# Max Damage Test Episode 8 finished with total reward: 5.52
# Max Damage Test Episode 9 finished with total reward: 5.52
# Max Damage Test Episode 10 finished with total reward: 5.40
# Max Damage Test Episode 11 finished with total reward: 5.30
# Max Damage Test Episode 12 finished with total reward: 3.85
# Max Damage Test Episode 13 finished with total reward: 5.54
# Max Damage Test Episode 14 finished with total reward: 5.34
# Max Damage Test Episode 15 finished with total reward: 5.81
# Max Damage Test Episode 16 finished with total reward: 5.36
# Max Damage Test Episode 17 finished with total reward: 5.27
# Max Damage Test Episode 18 finished with total reward: 5.40
# Max Damage Test Episode 19 finished with total reward: 4.36
# Max Damage Test Episode 20 finished with total reward: 4.00
# Max Damage Test Episode 21 finished with total reward: 2.98
# Max Damage Test Episode 22 finished with total reward: 5.61
# Max Damage Test Episode 23 finished with total reward: 5.18
# Max Damage Test Episode 24 finished with total reward: 5.27
# Max Damage Test Episode 25 finished with total reward: 2.22
# Max Damage Test Episode 26 finished with total reward: 5.36
# Max Damage Test Episode 27 finished with total reward: 5.48
# Max Damage Test Episode 28 finished with total reward: 5.77
# Max Damage Test Episode 29 finished with total reward: 5.45
# Max Damage Test Episode 30 finished with total reward: 5.30
# Max Damage Test Episode 31 finished with total reward: 5.52
# Max Damage Test Episode 32 finished with total reward: 5.18
# Max Damage Test Episode 33 finished with total reward: 3.49
# Max Damage Test Episode 34 finished with total reward: 3.47
# Max Damage Test Episode 35 finished with total reward: 5.30
# Max Damage Test Episode 36 finished with total reward: 5.40
# Max Damage Test Episode 37 finished with total reward: 4.24
# Max Damage Test Episode 38 finished with total reward: 2.53
# Max Damage Test Episode 39 finished with total reward: 5.74
# Max Damage Test Episode 40 finished with total reward: 5.31
# Max Damage Test Episode 41 finished with total reward: 3.45
# Max Damage Test Episode 42 finished with total reward: 5.27
# Max Damage Test Episode 43 finished with total reward: 4.07
# Max Damage Test Episode 44 finished with total reward: 5.27
# Max Damage Test Episode 45 finished with total reward: 5.25
# Max Damage Test Episode 46 finished with total reward: 2.94
# Max Damage Test Episode 47 finished with total reward: 5.33
# Max Damage Test Episode 48 finished with total reward: 5.21
# Max Damage Test Episode 49 finished with total reward: 5.32
# Max Damage Test Episode 50 finished with total reward: 5.22
# Max Damage Test Episode 51 finished with total reward: 5.26
# Max Damage Test Episode 52 finished with total reward: 3.44
# Max Damage Test Episode 53 finished with total reward: 5.44
# Max Damage Test Episode 54 finished with total reward: 5.28
# Max Damage Test Episode 55 finished with total reward: 5.28
# Max Damage Test Episode 56 finished with total reward: 5.98
# Max Damage Test Episode 57 finished with total reward: 5.30
# Max Damage Test Episode 58 finished with total reward: 5.27
# Max Damage Test Episode 59 finished with total reward: 3.69
# Max Damage Test Episode 60 finished with total reward: 5.21
# Max Damage Test Episode 61 finished with total reward: 5.32
# Max Damage Test Episode 62 finished with total reward: 3.56
# Max Damage Test Episode 63 finished with total reward: 3.97
# Max Damage Test Episode 64 finished with total reward: 4.40
# Max Damage Test Episode 65 finished with total reward: 5.29
# Max Damage Test Episode 66 finished with total reward: 2.75
# Max Damage Test Episode 67 finished with total reward: 3.43
# Max Damage Test Episode 68 finished with total reward: 5.46
# Max Damage Test Episode 69 finished with total reward: 2.83
# Max Damage Test Episode 70 finished with total reward: 5.22
# Max Damage Test Episode 71 finished with total reward: 1.94
# Max Damage Test Episode 72 finished with total reward: 5.54
# Max Damage Test Episode 73 finished with total reward: 5.17
# Max Damage Test Episode 74 finished with total reward: 5.60
# Max Damage Test Episode 75 finished with total reward: 3.39
# Max Damage Test Episode 76 finished with total reward: 5.39
# Max Damage Test Episode 77 finished with total reward: 5.64
# Max Damage Test Episode 78 finished with total reward: 4.19
# Max Damage Test Episode 79 finished with total reward: 5.47
# Max Damage Test Episode 80 finished with total reward: 5.10
# Max Damage Test Episode 81 finished with total reward: 3.00
# Max Damage Test Episode 82 finished with total reward: 3.33
# Max Damage Test Episode 83 finished with total reward: 5.51
# Max Damage Test Episode 84 finished with total reward: 2.32
# Max Damage Test Episode 85 finished with total reward: 5.46
# Max Damage Test Episode 86 finished with total reward: 3.06
# Max Damage Test Episode 87 finished with total reward: 5.38
# Max Damage Test Episode 88 finished with total reward: 5.11
# Max Damage Test Episode 89 finished with total reward: 5.20
# Max Damage Test Episode 90 finished with total reward: 5.15
# Max Damage Test Episode 91 finished with total reward: 5.37
# Max Damage Test Episode 92 finished with total reward: 5.29
# Max Damage Test Episode 93 finished with total reward: 5.66
# Max Damage Test Episode 94 finished with total reward: 5.49
# Max Damage Test Episode 95 finished with total reward: 5.23
# Max Damage Test Episode 96 finished with total reward: 3.29
# Max Damage Test Episode 97 finished with total reward: 5.46
# Max Damage Test Episode 98 finished with total reward: 5.29
# Max Damage Test Episode 99 finished with total reward: 5.36
# Max Damage Test Episode 100 finished with total reward: 3.39
# Max Damage Test Episode 101 finished with total reward: 5.28
# Max Damage Test Episode 102 finished with total reward: 5.24
# Max Damage Test Episode 103 finished with total reward: 2.89
# Max Damage Test Episode 104 finished with total reward: 4.11
# Max Damage Test Episode 105 finished with total reward: 5.44
# Max Damage Test Episode 106 finished with total reward: 5.25
# Max Damage Test Episode 107 finished with total reward: 2.88
# Max Damage Test Episode 108 finished with total reward: 2.99
# Max Damage Test Episode 109 finished with total reward: 4.10
# Max Damage Test Episode 110 finished with total reward: 3.15
# Max Damage Test Episode 111 finished with total reward: 3.21
# Max Damage Test Episode 112 finished with total reward: 3.45
# Max Damage Test Episode 113 finished with total reward: 5.39
# Max Damage Test Episode 114 finished with total reward: 3.72
# Max Damage Test Episode 115 finished with total reward: 5.35
# Max Damage Test Episode 116 finished with total reward: 5.55
# Max Damage Test Episode 117 finished with total reward: 4.16
# Max Damage Test Episode 118 finished with total reward: 5.36
# Max Damage Test Episode 119 finished with total reward: 5.37
# Max Damage Test Episode 120 finished with total reward: 2.00
# Max Damage Test Episode 121 finished with total reward: 5.27
# Max Damage Test Episode 122 finished with total reward: 5.15
# Max Damage Test Episode 123 finished with total reward: 4.16
# Max Damage Test Episode 124 finished with total reward: 5.44
# Max Damage Test Episode 125 finished with total reward: 5.24
# Max Damage Test Episode 126 finished with total reward: 5.58
# Max Damage Test Episode 127 finished with total reward: 5.41
# Max Damage Test Episode 128 finished with total reward: 5.67
# Max Damage Test Episode 129 finished with total reward: 3.61
# Max Damage Test Episode 130 finished with total reward: 2.37
# Max Damage Test Episode 131 finished with total reward: 5.31
# Max Damage Test Episode 132 finished with total reward: 5.20
# Max Damage Test Episode 133 finished with total reward: 3.31
# Max Damage Test Episode 134 finished with total reward: 3.28
# Max Damage Test Episode 135 finished with total reward: 2.31
# Max Damage Test Episode 136 finished with total reward: 5.30
# Max Damage Test Episode 137 finished with total reward: 5.26
# Max Damage Test Episode 138 finished with total reward: 4.11
# Max Damage Test Episode 139 finished with total reward: 3.61
# Max Damage Test Episode 140 finished with total reward: 3.05
# Max Damage Test Episode 141 finished with total reward: 5.44
# Max Damage Test Episode 142 finished with total reward: 3.76
# Max Damage Test Episode 143 finished with total reward: 3.99
# Max Damage Test Episode 144 finished with total reward: 5.68
# Max Damage Test Episode 145 finished with total reward: 4.18
# Max Damage Test Episode 146 finished with total reward: 4.19
# Max Damage Test Episode 147 finished with total reward: 4.03
# Max Damage Test Episode 148 finished with total reward: 5.25
# Max Damage Test Episode 149 finished with total reward: 4.02
# Max Damage Test Episode 150 finished with total reward: 5.44
# Max Damage Test Episode 151 finished with total reward: 6.08
# Max Damage Test Episode 152 finished with total reward: 5.46
# Max Damage Test Episode 153 finished with total reward: 5.30
# Max Damage Test Episode 154 finished with total reward: 6.00
# Max Damage Test Episode 155 finished with total reward: 5.73
# Max Damage Test Episode 156 finished with total reward: 2.99
# Max Damage Test Episode 157 finished with total reward: 5.35
# Max Damage Test Episode 158 finished with total reward: 3.69
# Max Damage Test Episode 159 finished with total reward: 3.00
# Max Damage Test Episode 160 finished with total reward: 2.97
# Max Damage Test Episode 161 finished with total reward: 5.29
# Max Damage Test Episode 162 finished with total reward: 3.70
# Max Damage Test Episode 163 finished with total reward: 5.57
# Max Damage Test Episode 164 finished with total reward: 3.97
# Max Damage Test Episode 165 finished with total reward: 5.24
# Max Damage Test Episode 166 finished with total reward: 3.40
# Max Damage Test Episode 167 finished with total reward: 5.45
# Max Damage Test Episode 168 finished with total reward: 3.65
# Max Damage Test Episode 169 finished with total reward: 5.29
# Max Damage Test Episode 170 finished with total reward: 5.34
# Max Damage Test Episode 171 finished with total reward: 5.60
# Max Damage Test Episode 172 finished with total reward: 3.25
# Max Damage Test Episode 173 finished with total reward: 0.90
# Max Damage Test Episode 174 finished with total reward: 3.02
# Max Damage Test Episode 175 finished with total reward: 3.31
# Max Damage Test Episode 176 finished with total reward: 3.71
# Max Damage Test Episode 177 finished with total reward: 3.71
# Max Damage Test Episode 178 finished with total reward: 5.19
# Max Damage Test Episode 179 finished with total reward: 5.33
# Max Damage Test Episode 180 finished with total reward: 5.46
# Max Damage Test Episode 181 finished with total reward: 5.39
# Max Damage Test Episode 182 finished with total reward: 5.41
# Max Damage Test Episode 183 finished with total reward: 4.01
# Max Damage Test Episode 184 finished with total reward: 5.58
# Max Damage Test Episode 185 finished with total reward: 3.36
# Max Damage Test Episode 186 finished with total reward: 5.50
# Max Damage Test Episode 187 finished with total reward: 5.27
# Max Damage Test Episode 188 finished with total reward: 5.33
# Max Damage Test Episode 189 finished with total reward: 5.21
# Max Damage Test Episode 190 finished with total reward: 3.44
# Max Damage Test Episode 191 finished with total reward: 2.84
# Max Damage Test Episode 192 finished with total reward: 5.36
# Max Damage Test Episode 193 finished with total reward: 5.30
# Max Damage Test Episode 194 finished with total reward: 3.46
# Max Damage Test Episode 195 finished with total reward: 2.15
# Max Damage Test Episode 196 finished with total reward: 5.27
# Max Damage Test Episode 197 finished with total reward: 3.99
# Max Damage Test Episode 198 finished with total reward: 4.34
# Max Damage Test Episode 199 finished with total reward: 4.11
# Max Damage Test Episode 200 finished with total reward: 4.04
# Max Damage Test Episode 201 finished with total reward: 5.30
# Max Damage Test Episode 202 finished with total reward: 3.84
# Max Damage Test Episode 203 finished with total reward: 4.24
# Max Damage Test Episode 204 finished with total reward: 3.44
# Max Damage Test Episode 205 finished with total reward: 5.47
# Max Damage Test Episode 206 finished with total reward: 5.31
# Max Damage Test Episode 207 finished with total reward: 5.45
# Max Damage Test Episode 208 finished with total reward: 5.36
# Max Damage Test Episode 209 finished with total reward: 3.79
# Max Damage Test Episode 210 finished with total reward: 4.09
# Max Damage Test Episode 211 finished with total reward: 5.58
# Max Damage Test Episode 212 finished with total reward: 5.42
# Max Damage Test Episode 213 finished with total reward: 5.51
# Max Damage Test Episode 214 finished with total reward: 5.62
# Max Damage Test Episode 215 finished with total reward: 5.52
# Max Damage Test Episode 216 finished with total reward: 5.51
# Max Damage Test Episode 217 finished with total reward: 3.81
# Max Damage Test Episode 218 finished with total reward: 5.19
# Max Damage Test Episode 219 finished with total reward: 5.18
# Max Damage Test Episode 220 finished with total reward: 1.84
# Max Damage Test Episode 221 finished with total reward: 5.43
# Max Damage Test Episode 222 finished with total reward: 3.23
# Max Damage Test Episode 223 finished with total reward: 5.25
# Max Damage Test Episode 224 finished with total reward: 3.90
# Max Damage Test Episode 225 finished with total reward: 5.30
# Max Damage Test Episode 226 finished with total reward: 5.12
# Max Damage Test Episode 227 finished with total reward: 5.49
# Max Damage Test Episode 228 finished with total reward: 5.86
# Max Damage Test Episode 229 finished with total reward: 5.17
# Max Damage Test Episode 230 finished with total reward: 5.15
# Max Damage Test Episode 231 finished with total reward: 3.56
# Max Damage Test Episode 232 finished with total reward: 5.16
# Max Damage Test Episode 233 finished with total reward: 5.33
# Max Damage Test Episode 234 finished with total reward: 2.30
# Max Damage Test Episode 235 finished with total reward: 4.17
# Max Damage Test Episode 236 finished with total reward: 5.27
# Max Damage Test Episode 237 finished with total reward: 5.44
# Max Damage Test Episode 238 finished with total reward: 5.49
# Max Damage Test Episode 239 finished with total reward: 4.51
# Max Damage Test Episode 240 finished with total reward: 5.56
# Max Damage Test Episode 241 finished with total reward: 3.45
# Max Damage Test Episode 242 finished with total reward: 5.29
# Max Damage Test Episode 243 finished with total reward: 4.10
# Max Damage Test Episode 244 finished with total reward: 5.30
# Max Damage Test Episode 245 finished with total reward: 5.26
# Max Damage Test Episode 246 finished with total reward: 5.58
# Max Damage Test Episode 247 finished with total reward: 5.26
# Max Damage Test Episode 248 finished with total reward: 5.36
# Max Damage Test Episode 249 finished with total reward: 3.78
# Max Damage Test Episode 250 finished with total reward: 5.63
# Max Damage Test Episode 251 finished with total reward: 5.22
# Max Damage Test Episode 252 finished with total reward: 5.47
# Max Damage Test Episode 253 finished with total reward: 4.16
# Max Damage Test Episode 254 finished with total reward: 5.35
# Max Damage Test Episode 255 finished with total reward: 4.15
# Max Damage Test Episode 256 finished with total reward: 2.42
# Max Damage Test Episode 257 finished with total reward: 5.38
# Max Damage Test Episode 258 finished with total reward: 2.62
# Max Damage Test Episode 259 finished with total reward: 5.68
# Max Damage Test Episode 260 finished with total reward: 2.70
# Max Damage Test Episode 261 finished with total reward: 5.27
# Max Damage Test Episode 262 finished with total reward: 3.90
# Max Damage Test Episode 263 finished with total reward: 5.29
# Max Damage Test Episode 264 finished with total reward: 5.40
# Max Damage Test Episode 265 finished with total reward: 5.54
# Max Damage Test Episode 266 finished with total reward: 5.22
# Max Damage Test Episode 267 finished with total reward: 5.31
# Max Damage Test Episode 268 finished with total reward: 5.40
# Max Damage Test Episode 269 finished with total reward: 6.00
# Max Damage Test Episode 270 finished with total reward: 5.27
# Max Damage Test Episode 271 finished with total reward: 3.17
# Max Damage Test Episode 272 finished with total reward: 5.61
# Max Damage Test Episode 273 finished with total reward: 2.67
# Max Damage Test Episode 274 finished with total reward: 5.29
# Max Damage Test Episode 275 finished with total reward: 3.80
# Max Damage Test Episode 276 finished with total reward: 3.11
# Max Damage Test Episode 277 finished with total reward: 3.80
# Max Damage Test Episode 278 finished with total reward: 5.24
# Max Damage Test Episode 279 finished with total reward: 3.47
# Max Damage Test Episode 280 finished with total reward: 5.18
# Max Damage Test Episode 281 finished with total reward: 5.26
# Max Damage Test Episode 282 finished with total reward: 5.24
# Max Damage Test Episode 283 finished with total reward: 5.23
# Max Damage Test Episode 284 finished with total reward: 5.42
# Max Damage Test Episode 285 finished with total reward: 3.28
# Max Damage Test Episode 286 finished with total reward: 5.20
# Max Damage Test Episode 287 finished with total reward: 5.49
# Max Damage Test Episode 288 finished with total reward: 3.48
# Max Damage Test Episode 289 finished with total reward: 3.44
# Max Damage Test Episode 290 finished with total reward: 2.03
# Max Damage Test Episode 291 finished with total reward: 3.66
# Max Damage Test Episode 292 finished with total reward: 5.78
# Max Damage Test Episode 293 finished with total reward: 5.64
# Max Damage Test Episode 294 finished with total reward: 5.22
# Max Damage Test Episode 295 finished with total reward: 5.59
# Max Damage Test Episode 296 finished with total reward: 5.27
# Max Damage Test Episode 297 finished with total reward: 2.90
# Max Damage Test Episode 298 finished with total reward: 5.50
# Max Damage Test Episode 299 finished with total reward: 5.59
# Max Damage Test Episode 300 finished with total reward: 5.51
# Max Damage Test Episode 301 finished with total reward: 5.37
# Max Damage Test Episode 302 finished with total reward: 5.31
# Max Damage Test Episode 303 finished with total reward: 3.70
# Max Damage Test Episode 304 finished with total reward: 5.53
# Max Damage Test Episode 305 finished with total reward: 5.19
# Max Damage Test Episode 306 finished with total reward: 4.06
# Max Damage Test Episode 307 finished with total reward: 5.30
# Max Damage Test Episode 308 finished with total reward: 5.51
# Max Damage Test Episode 309 finished with total reward: 5.31
# Max Damage Test Episode 310 finished with total reward: 5.46
# Max Damage Test Episode 311 finished with total reward: 5.40
# Max Damage Test Episode 312 finished with total reward: 3.36
# Max Damage Test Episode 313 finished with total reward: 5.27
# Max Damage Test Episode 314 finished with total reward: 5.26
# Max Damage Test Episode 315 finished with total reward: 5.20
# Max Damage Test Episode 316 finished with total reward: 5.21
# Max Damage Test Episode 317 finished with total reward: 4.26
# Max Damage Test Episode 318 finished with total reward: 5.43
# Max Damage Test Episode 319 finished with total reward: 2.57
# Max Damage Test Episode 320 finished with total reward: 5.29
# Max Damage Test Episode 321 finished with total reward: 3.44
# Max Damage Test Episode 322 finished with total reward: 2.42
# Max Damage Test Episode 323 finished with total reward: 5.25
# Max Damage Test Episode 324 finished with total reward: 5.50
# Max Damage Test Episode 325 finished with total reward: 5.44
# Max Damage Test Episode 326 finished with total reward: 3.20
# Max Damage Test Episode 327 finished with total reward: 5.39
# Max Damage Test Episode 328 finished with total reward: 3.00
# Max Damage Test Episode 329 finished with total reward: 5.29
# Max Damage Test Episode 330 finished with total reward: 5.40
# Max Damage Test Episode 331 finished with total reward: 5.43
# Max Damage Test Episode 332 finished with total reward: 5.38
# Max Damage Test Episode 333 finished with total reward: 3.88
# Max Damage Test Episode 334 finished with total reward: 5.76
# Max Damage Test Episode 335 finished with total reward: 5.36
# Max Damage Test Episode 336 finished with total reward: 5.26
# Max Damage Test Episode 337 finished with total reward: 5.31
# Max Damage Test Episode 338 finished with total reward: 3.18
# Max Damage Test Episode 339 finished with total reward: 3.16
# Max Damage Test Episode 340 finished with total reward: 5.52
# Max Damage Test Episode 341 finished with total reward: 3.79
# Max Damage Test Episode 342 finished with total reward: 5.46
# Max Damage Test Episode 343 finished with total reward: 6.04
# Max Damage Test Episode 344 finished with total reward: 3.23
# Max Damage Test Episode 345 finished with total reward: 3.23
# Max Damage Test Episode 346 finished with total reward: 5.61
# Max Damage Test Episode 347 finished with total reward: 5.36
# Max Damage Test Episode 348 finished with total reward: 4.05
# Max Damage Test Episode 349 finished with total reward: 3.69
# Max Damage Test Episode 350 finished with total reward: 2.41
# Max Damage Test Episode 351 finished with total reward: 5.23
# Max Damage Test Episode 352 finished with total reward: 5.13
# Max Damage Test Episode 353 finished with total reward: 5.29
# Max Damage Test Episode 354 finished with total reward: 3.92
# Max Damage Test Episode 355 finished with total reward: 5.30
# Max Damage Test Episode 356 finished with total reward: 5.12
# Max Damage Test Episode 357 finished with total reward: 3.75
# Max Damage Test Episode 358 finished with total reward: 5.34
# Max Damage Test Episode 359 finished with total reward: 5.24
# Max Damage Test Episode 360 finished with total reward: 5.14
# Max Damage Test Episode 361 finished with total reward: 4.06
# Max Damage Test Episode 362 finished with total reward: 5.26
# Max Damage Test Episode 363 finished with total reward: 5.20
# Max Damage Test Episode 364 finished with total reward: 0.96
# Max Damage Test Episode 365 finished with total reward: 5.26
# Max Damage Test Episode 366 finished with total reward: 5.36
# Max Damage Test Episode 367 finished with total reward: 2.81
# Max Damage Test Episode 368 finished with total reward: 5.50
# Max Damage Test Episode 369 finished with total reward: 3.30
# Max Damage Test Episode 370 finished with total reward: 5.55
# Max Damage Test Episode 371 finished with total reward: 3.25
# Max Damage Test Episode 372 finished with total reward: 3.62
# Max Damage Test Episode 373 finished with total reward: 5.40
# Max Damage Test Episode 374 finished with total reward: 3.15
# Max Damage Test Episode 375 finished with total reward: 4.04
# Max Damage Test Episode 376 finished with total reward: 5.33
# Max Damage Test Episode 377 finished with total reward: 4.19
# Max Damage Test Episode 378 finished with total reward: 3.53
# Max Damage Test Episode 379 finished with total reward: 5.25
# Max Damage Test Episode 380 finished with total reward: 5.50
# Max Damage Test Episode 381 finished with total reward: 5.34
# Max Damage Test Episode 382 finished with total reward: 3.78
# Max Damage Test Episode 383 finished with total reward: 5.35
# Max Damage Test Episode 384 finished with total reward: 5.44
# Max Damage Test Episode 385 finished with total reward: 5.11
# Max Damage Test Episode 386 finished with total reward: 6.12
# Max Damage Test Episode 387 finished with total reward: 5.22
# Max Damage Test Episode 388 finished with total reward: 3.76
# Max Damage Test Episode 389 finished with total reward: 4.08
# Max Damage Test Episode 390 finished with total reward: 2.47
# Max Damage Test Episode 391 finished with total reward: 5.23
# Max Damage Test Episode 392 finished with total reward: 5.75
# Max Damage Test Episode 393 finished with total reward: 4.19
# Max Damage Test Episode 394 finished with total reward: 5.34
# Max Damage Test Episode 395 finished with total reward: 2.93
# Max Damage Test Episode 396 finished with total reward: 3.05
# Max Damage Test Episode 397 finished with total reward: 5.55
# Max Damage Test Episode 398 finished with total reward: 3.55
# Max Damage Test Episode 399 finished with total reward: 5.43
# Max Damage Test Episode 400 finished with total reward: 5.48
# Max Damage Test Episode 401 finished with total reward: 5.56
# Max Damage Test Episode 402 finished with total reward: 5.46
# Max Damage Test Episode 403 finished with total reward: 5.37
# Max Damage Test Episode 404 finished with total reward: 3.81
# Max Damage Test Episode 405 finished with total reward: 3.22
# Max Damage Test Episode 406 finished with total reward: 2.76
# Max Damage Test Episode 407 finished with total reward: 3.27
# Max Damage Test Episode 408 finished with total reward: 5.32
# Max Damage Test Episode 409 finished with total reward: 5.42
# Max Damage Test Episode 410 finished with total reward: 5.34
# Max Damage Test Episode 411 finished with total reward: 3.53
# Max Damage Test Episode 412 finished with total reward: 5.34
# Max Damage Test Episode 413 finished with total reward: 5.24
# Max Damage Test Episode 414 finished with total reward: 5.29
# Max Damage Test Episode 415 finished with total reward: 3.81
# Max Damage Test Episode 416 finished with total reward: 5.38
# Max Damage Test Episode 417 finished with total reward: 5.41
# Max Damage Test Episode 418 finished with total reward: 5.42
# Max Damage Test Episode 419 finished with total reward: 3.80
# Max Damage Test Episode 420 finished with total reward: 3.72
# Max Damage Test Episode 421 finished with total reward: 3.20
# Max Damage Test Episode 422 finished with total reward: 3.15
# Max Damage Test Episode 423 finished with total reward: 3.11
# Max Damage Test Episode 424 finished with total reward: 5.27
# Max Damage Test Episode 425 finished with total reward: 3.08
# Max Damage Test Episode 426 finished with total reward: 5.41
# Max Damage Test Episode 427 finished with total reward: 5.26
# Max Damage Test Episode 428 finished with total reward: 2.72
# Max Damage Test Episode 429 finished with total reward: 5.84
# Max Damage Test Episode 430 finished with total reward: 5.29
# Max Damage Test Episode 431 finished with total reward: 5.55
# Max Damage Test Episode 432 finished with total reward: 3.03
# Max Damage Test Episode 433 finished with total reward: 2.73
# Max Damage Test Episode 434 finished with total reward: 3.36
# Max Damage Test Episode 435 finished with total reward: 5.49
# Max Damage Test Episode 436 finished with total reward: 5.39
# Max Damage Test Episode 437 finished with total reward: 5.22
# Max Damage Test Episode 438 finished with total reward: 5.07
# Max Damage Test Episode 439 finished with total reward: 4.01
# Max Damage Test Episode 440 finished with total reward: 5.72
# Max Damage Test Episode 441 finished with total reward: 5.46
# Max Damage Test Episode 442 finished with total reward: 3.85
# Max Damage Test Episode 443 finished with total reward: 5.36
# Max Damage Test Episode 444 finished with total reward: 3.75
# Max Damage Test Episode 445 finished with total reward: 5.61
# Max Damage Test Episode 446 finished with total reward: 5.44
# Max Damage Test Episode 447 finished with total reward: 5.42
# Max Damage Test Episode 448 finished with total reward: 5.35
# Max Damage Test Episode 449 finished with total reward: 5.39
# Max Damage Test Episode 450 finished with total reward: 5.05
# Max Damage Test Episode 451 finished with total reward: 5.34
# Max Damage Test Episode 452 finished with total reward: 5.22
# Max Damage Test Episode 453 finished with total reward: 1.81
# Max Damage Test Episode 454 finished with total reward: 3.48
# Max Damage Test Episode 455 finished with total reward: 3.26
# Max Damage Test Episode 456 finished with total reward: 5.43
# Max Damage Test Episode 457 finished with total reward: 3.56
# Max Damage Test Episode 458 finished with total reward: 5.32
# Max Damage Test Episode 459 finished with total reward: 5.43
# Max Damage Test Episode 460 finished with total reward: 2.74
# Max Damage Test Episode 461 finished with total reward: 3.22
# Max Damage Test Episode 462 finished with total reward: 3.19
# Max Damage Test Episode 463 finished with total reward: 5.46
# Max Damage Test Episode 464 finished with total reward: 5.29
# Max Damage Test Episode 465 finished with total reward: 5.50
# Max Damage Test Episode 466 finished with total reward: 4.12
# Max Damage Test Episode 467 finished with total reward: 3.87
# Max Damage Test Episode 468 finished with total reward: 5.17
# Max Damage Test Episode 469 finished with total reward: 5.33
# Max Damage Test Episode 470 finished with total reward: 5.38
# Max Damage Test Episode 471 finished with total reward: 5.59
# Max Damage Test Episode 472 finished with total reward: 5.28
# Max Damage Test Episode 473 finished with total reward: 5.90
# Max Damage Test Episode 474 finished with total reward: 3.56
# Max Damage Test Episode 475 finished with total reward: 4.28
# Max Damage Test Episode 476 finished with total reward: 3.45
# Max Damage Test Episode 477 finished with total reward: 4.17
# Max Damage Test Episode 478 finished with total reward: 4.41
# Max Damage Test Episode 479 finished with total reward: 5.99
# Max Damage Test Episode 480 finished with total reward: 3.33
# Max Damage Test Episode 481 finished with total reward: 5.43
# Max Damage Test Episode 482 finished with total reward: 2.86
# Max Damage Test Episode 483 finished with total reward: 4.03
# Max Damage Test Episode 484 finished with total reward: 5.32
# Max Damage Test Episode 485 finished with total reward: 5.69
# Max Damage Test Episode 486 finished with total reward: 5.26
# Max Damage Test Episode 487 finished with total reward: 3.83
# Max Damage Test Episode 488 finished with total reward: 5.46
# Max Damage Test Episode 489 finished with total reward: 5.23
# Max Damage Test Episode 490 finished with total reward: 5.27
# Max Damage Test Episode 491 finished with total reward: 5.29
# Max Damage Test Episode 492 finished with total reward: 5.16
# Max Damage Test Episode 493 finished with total reward: 3.80
# Max Damage Test Episode 494 finished with total reward: 5.38
# Max Damage Test Episode 495 finished with total reward: 3.41
# Max Damage Test Episode 496 finished with total reward: 3.55
# Max Damage Test Episode 497 finished with total reward: 5.16
# Max Damage Test Episode 498 finished with total reward: 4.24
# Max Damage Test Episode 499 finished with total reward: 2.76
# Max Damage Test Episode 500 finished with total reward: 5.55
# Max Damage Test Episode 501 finished with total reward: 5.55
# Max Damage Test Episode 502 finished with total reward: 3.63
# Max Damage Test Episode 503 finished with total reward: 5.42
# Max Damage Test Episode 504 finished with total reward: 3.69
# Max Damage Test Episode 505 finished with total reward: 5.36
# Max Damage Test Episode 506 finished with total reward: 2.76
# Max Damage Test Episode 507 finished with total reward: 5.38
# Max Damage Test Episode 508 finished with total reward: 5.51
# Max Damage Test Episode 509 finished with total reward: 5.63
# Max Damage Test Episode 510 finished with total reward: 5.71
# Max Damage Test Episode 511 finished with total reward: 5.42
# Max Damage Test Episode 512 finished with total reward: 5.21
# Max Damage Test Episode 513 finished with total reward: 5.28
# Max Damage Test Episode 514 finished with total reward: 5.46
# Max Damage Test Episode 515 finished with total reward: 3.79
# Max Damage Test Episode 516 finished with total reward: 5.60
# Max Damage Test Episode 517 finished with total reward: 3.82
# Max Damage Test Episode 518 finished with total reward: 5.54
# Max Damage Test Episode 519 finished with total reward: 3.96
# Max Damage Test Episode 520 finished with total reward: 2.87
# Max Damage Test Episode 521 finished with total reward: 2.39
# Max Damage Test Episode 522 finished with total reward: 5.33
# Max Damage Test Episode 523 finished with total reward: 5.65
# Max Damage Test Episode 524 finished with total reward: 5.03
# Max Damage Test Episode 525 finished with total reward: 3.29
# Max Damage Test Episode 526 finished with total reward: 5.48
# Max Damage Test Episode 527 finished with total reward: 5.42
# Max Damage Test Episode 528 finished with total reward: 5.29
# Max Damage Test Episode 529 finished with total reward: 5.35
# Max Damage Test Episode 530 finished with total reward: 3.14
# Max Damage Test Episode 531 finished with total reward: 5.09
# Max Damage Test Episode 532 finished with total reward: 5.41
# Max Damage Test Episode 533 finished with total reward: 4.18
# Max Damage Test Episode 534 finished with total reward: 5.44
# Max Damage Test Episode 535 finished with total reward: 5.53
# Max Damage Test Episode 536 finished with total reward: 5.18
# Max Damage Test Episode 537 finished with total reward: 4.53
# Max Damage Test Episode 538 finished with total reward: 5.36
# Max Damage Test Episode 539 finished with total reward: 5.24
# Max Damage Test Episode 540 finished with total reward: 5.28
# Max Damage Test Episode 541 finished with total reward: 3.49
# Max Damage Test Episode 542 finished with total reward: 5.30
# Max Damage Test Episode 543 finished with total reward: 3.70
# Max Damage Test Episode 544 finished with total reward: 5.15
# Max Damage Test Episode 545 finished with total reward: 5.26
# Max Damage Test Episode 546 finished with total reward: 5.81
# Max Damage Test Episode 547 finished with total reward: 5.37
# Max Damage Test Episode 548 finished with total reward: 5.38
# Max Damage Test Episode 549 finished with total reward: 3.67
# Max Damage Test Episode 550 finished with total reward: 3.56
# Max Damage Test Episode 551 finished with total reward: 5.49
# Max Damage Test Episode 552 finished with total reward: 5.69
# Max Damage Test Episode 553 finished with total reward: 3.88
# Max Damage Test Episode 554 finished with total reward: 5.23
# Max Damage Test Episode 555 finished with total reward: 5.37
# Max Damage Test Episode 556 finished with total reward: 5.23
# Max Damage Test Episode 557 finished with total reward: 5.11
# Max Damage Test Episode 558 finished with total reward: 3.26
# Max Damage Test Episode 559 finished with total reward: 4.00
# Max Damage Test Episode 560 finished with total reward: 5.56
# Max Damage Test Episode 561 finished with total reward: 5.34
# Max Damage Test Episode 562 finished with total reward: 3.56
# Max Damage Test Episode 563 finished with total reward: 5.39
# Max Damage Test Episode 564 finished with total reward: 5.40
# Max Damage Test Episode 565 finished with total reward: 5.32
# Max Damage Test Episode 566 finished with total reward: 2.72
# Max Damage Test Episode 567 finished with total reward: 2.85
# Max Damage Test Episode 568 finished with total reward: 5.34
# Max Damage Test Episode 569 finished with total reward: 4.04
# Max Damage Test Episode 570 finished with total reward: 3.66
# Max Damage Test Episode 571 finished with total reward: 5.44
# Max Damage Test Episode 572 finished with total reward: 5.39
# Max Damage Test Episode 573 finished with total reward: 3.99
# Max Damage Test Episode 574 finished with total reward: 5.17
# Max Damage Test Episode 575 finished with total reward: 5.73
# Max Damage Test Episode 576 finished with total reward: 5.43
# Max Damage Test Episode 577 finished with total reward: 0.94
# Max Damage Test Episode 578 finished with total reward: 5.26
# Max Damage Test Episode 579 finished with total reward: 5.14
# Max Damage Test Episode 580 finished with total reward: 5.43
# Max Damage Test Episode 581 finished with total reward: 3.87
# Max Damage Test Episode 582 finished with total reward: 5.31
# Max Damage Test Episode 583 finished with total reward: 5.16
# Max Damage Test Episode 584 finished with total reward: 3.91
# Max Damage Test Episode 585 finished with total reward: 2.69
# Max Damage Test Episode 586 finished with total reward: 3.30
# Max Damage Test Episode 587 finished with total reward: 3.26
# Max Damage Test Episode 588 finished with total reward: 2.95
# Max Damage Test Episode 589 finished with total reward: 5.62
# Max Damage Test Episode 590 finished with total reward: 4.17
# Max Damage Test Episode 591 finished with total reward: 2.51
# Max Damage Test Episode 592 finished with total reward: 3.72
# Max Damage Test Episode 593 finished with total reward: 5.20
# Max Damage Test Episode 594 finished with total reward: 3.89
# Max Damage Test Episode 595 finished with total reward: 5.41
# Max Damage Test Episode 596 finished with total reward: 5.21
# Max Damage Test Episode 597 finished with total reward: 5.23
# Max Damage Test Episode 598 finished with total reward: 5.19
# Max Damage Test Episode 599 finished with total reward: 5.19
# Max Damage Test Episode 600 finished with total reward: 5.68
# Max Damage Test Episode 601 finished with total reward: 5.38
# Max Damage Test Episode 602 finished with total reward: 2.59
# Max Damage Test Episode 603 finished with total reward: 5.39
# Max Damage Test Episode 604 finished with total reward: 5.26
# Max Damage Test Episode 605 finished with total reward: 2.91
# Max Damage Test Episode 606 finished with total reward: 5.38
# Max Damage Test Episode 607 finished with total reward: 3.74
# Max Damage Test Episode 608 finished with total reward: 3.92
# Max Damage Test Episode 609 finished with total reward: 3.78
# Max Damage Test Episode 610 finished with total reward: 5.51
# Max Damage Test Episode 611 finished with total reward: 5.24
# Max Damage Test Episode 612 finished with total reward: 3.78
# Max Damage Test Episode 613 finished with total reward: 4.34
# Max Damage Test Episode 614 finished with total reward: 3.49
# Max Damage Test Episode 615 finished with total reward: 5.31
# Max Damage Test Episode 616 finished with total reward: 5.44
# Max Damage Test Episode 617 finished with total reward: 5.43
# Max Damage Test Episode 618 finished with total reward: 3.71
# Max Damage Test Episode 619 finished with total reward: 5.29
# Max Damage Test Episode 620 finished with total reward: 5.40
# Max Damage Test Episode 621 finished with total reward: 2.99
# Max Damage Test Episode 622 finished with total reward: 5.37
# Max Damage Test Episode 623 finished with total reward: 5.39
# Max Damage Test Episode 624 finished with total reward: 5.19
# Max Damage Test Episode 625 finished with total reward: 3.77
# Max Damage Test Episode 626 finished with total reward: 3.26
# Max Damage Test Episode 627 finished with total reward: 5.19
# Max Damage Test Episode 628 finished with total reward: 4.07
# Max Damage Test Episode 629 finished with total reward: 5.61
# Max Damage Test Episode 630 finished with total reward: 5.41
# Max Damage Test Episode 631 finished with total reward: 3.95
# Max Damage Test Episode 632 finished with total reward: 3.29
# Max Damage Test Episode 633 finished with total reward: 3.96
# Max Damage Test Episode 634 finished with total reward: 5.10
# Max Damage Test Episode 635 finished with total reward: 3.59
# Max Damage Test Episode 636 finished with total reward: 3.29
# Max Damage Test Episode 637 finished with total reward: 5.67
# Max Damage Test Episode 638 finished with total reward: 3.95
# Max Damage Test Episode 639 finished with total reward: 5.54
# Max Damage Test Episode 640 finished with total reward: 2.80
# Max Damage Test Episode 641 finished with total reward: 5.68
# Max Damage Test Episode 642 finished with total reward: 5.18
# Max Damage Test Episode 643 finished with total reward: 5.18
# Max Damage Test Episode 644 finished with total reward: 5.11
# Max Damage Test Episode 645 finished with total reward: 5.54
# Max Damage Test Episode 646 finished with total reward: 5.22
# Max Damage Test Episode 647 finished with total reward: 5.72
# Max Damage Test Episode 648 finished with total reward: 3.20
# Max Damage Test Episode 649 finished with total reward: 2.58
# Max Damage Test Episode 650 finished with total reward: 5.19
# Max Damage Test Episode 651 finished with total reward: 5.30
# Max Damage Test Episode 652 finished with total reward: 5.48
# Max Damage Test Episode 653 finished with total reward: 4.36
# Max Damage Test Episode 654 finished with total reward: 3.71
# Max Damage Test Episode 655 finished with total reward: 5.34
# Max Damage Test Episode 656 finished with total reward: 5.38
# Max Damage Test Episode 657 finished with total reward: 6.04
# Max Damage Test Episode 658 finished with total reward: 5.12
# Max Damage Test Episode 659 finished with total reward: 5.12
# Max Damage Test Episode 660 finished with total reward: 5.25
# Max Damage Test Episode 661 finished with total reward: 5.66
# Max Damage Test Episode 662 finished with total reward: 5.15
# Max Damage Test Episode 663 finished with total reward: 3.52
# Max Damage Test Episode 664 finished with total reward: 5.10
# Max Damage Test Episode 665 finished with total reward: 5.66
# Max Damage Test Episode 666 finished with total reward: 3.49
# Max Damage Test Episode 667 finished with total reward: 2.89
# Max Damage Test Episode 668 finished with total reward: 5.36
# Max Damage Test Episode 669 finished with total reward: 3.79
# Max Damage Test Episode 670 finished with total reward: 3.71
# Max Damage Test Episode 671 finished with total reward: 4.05
# Max Damage Test Episode 672 finished with total reward: 5.93
# Max Damage Test Episode 673 finished with total reward: 3.73
# Max Damage Test Episode 674 finished with total reward: 3.43
# Max Damage Test Episode 675 finished with total reward: 5.40
# Max Damage Test Episode 676 finished with total reward: 3.73
# Max Damage Test Episode 677 finished with total reward: 4.25
# Max Damage Test Episode 678 finished with total reward: 5.26
# Max Damage Test Episode 679 finished with total reward: 5.30
# Max Damage Test Episode 680 finished with total reward: 2.09
# Max Damage Test Episode 681 finished with total reward: 3.17
# Max Damage Test Episode 682 finished with total reward: 5.38
# Max Damage Test Episode 683 finished with total reward: 5.53
# Max Damage Test Episode 684 finished with total reward: 5.60
# Max Damage Test Episode 685 finished with total reward: 5.08
# Max Damage Test Episode 686 finished with total reward: 2.15
# Max Damage Test Episode 687 finished with total reward: 2.81
# Max Damage Test Episode 688 finished with total reward: 5.30
# Max Damage Test Episode 689 finished with total reward: 5.58
# Max Damage Test Episode 690 finished with total reward: 5.49
# Max Damage Test Episode 691 finished with total reward: 3.16
# Max Damage Test Episode 692 finished with total reward: 5.23
# Max Damage Test Episode 693 finished with total reward: 3.00
# Max Damage Test Episode 694 finished with total reward: 3.75
# Max Damage Test Episode 695 finished with total reward: 3.77
# Max Damage Test Episode 696 finished with total reward: 3.50
# Max Damage Test Episode 697 finished with total reward: 5.26
# Max Damage Test Episode 698 finished with total reward: 5.41
# Max Damage Test Episode 699 finished with total reward: 5.38
# Max Damage Test Episode 700 finished with total reward: 3.24
# Max Damage Test Episode 701 finished with total reward: 5.36
# Max Damage Test Episode 702 finished with total reward: 5.38
# Max Damage Test Episode 703 finished with total reward: 3.97
# Max Damage Test Episode 704 finished with total reward: 5.25
# Max Damage Test Episode 705 finished with total reward: 3.10
# Max Damage Test Episode 706 finished with total reward: 5.49
# Max Damage Test Episode 707 finished with total reward: 5.21
# Max Damage Test Episode 708 finished with total reward: 5.32
# Max Damage Test Episode 709 finished with total reward: 2.77
# Max Damage Test Episode 710 finished with total reward: 5.37
# Max Damage Test Episode 711 finished with total reward: 3.50
# Max Damage Test Episode 712 finished with total reward: 5.16
# Max Damage Test Episode 713 finished with total reward: 5.35
# Max Damage Test Episode 714 finished with total reward: 5.44
# Max Damage Test Episode 715 finished with total reward: 5.53
# Max Damage Test Episode 716 finished with total reward: 5.26
# Max Damage Test Episode 717 finished with total reward: 4.05
# Max Damage Test Episode 718 finished with total reward: 2.93
# Max Damage Test Episode 719 finished with total reward: 5.27
# Max Damage Test Episode 720 finished with total reward: 5.48
# Max Damage Test Episode 721 finished with total reward: 3.72
# Max Damage Test Episode 722 finished with total reward: 5.47
# Max Damage Test Episode 723 finished with total reward: 3.91
# Max Damage Test Episode 724 finished with total reward: 3.79
# Max Damage Test Episode 725 finished with total reward: 5.10
# Max Damage Test Episode 726 finished with total reward: 5.46
# Max Damage Test Episode 727 finished with total reward: 5.45
# Max Damage Test Episode 728 finished with total reward: 3.10
# Max Damage Test Episode 729 finished with total reward: 5.44
# Max Damage Test Episode 730 finished with total reward: 5.13
# Max Damage Test Episode 731 finished with total reward: 3.48
# Max Damage Test Episode 732 finished with total reward: 4.22
# Max Damage Test Episode 733 finished with total reward: 3.46
# Max Damage Test Episode 734 finished with total reward: 4.27
# Max Damage Test Episode 735 finished with total reward: 5.43
# Max Damage Test Episode 736 finished with total reward: 3.77
# Max Damage Test Episode 737 finished with total reward: 5.16
# Max Damage Test Episode 738 finished with total reward: 5.27
# Max Damage Test Episode 739 finished with total reward: 5.38
# Max Damage Test Episode 740 finished with total reward: 5.56
# Max Damage Test Episode 741 finished with total reward: 5.62
# Max Damage Test Episode 742 finished with total reward: 5.14
# Max Damage Test Episode 743 finished with total reward: 5.57
# Max Damage Test Episode 744 finished with total reward: 5.30
# Max Damage Test Episode 745 finished with total reward: 5.28
# Max Damage Test Episode 746 finished with total reward: 5.28
# Max Damage Test Episode 747 finished with total reward: 5.31
# Max Damage Test Episode 748 finished with total reward: 5.30
# Max Damage Test Episode 749 finished with total reward: 2.91
# Max Damage Test Episode 750 finished with total reward: 3.38
# Max Damage Test Episode 751 finished with total reward: 5.46
# Max Damage Test Episode 752 finished with total reward: 5.49
# Max Damage Test Episode 753 finished with total reward: 5.66
# Max Damage Test Episode 754 finished with total reward: 3.87
# Max Damage Test Episode 755 finished with total reward: 5.32
# Max Damage Test Episode 756 finished with total reward: 3.95
# Max Damage Test Episode 757 finished with total reward: 5.57
# Max Damage Test Episode 758 finished with total reward: 5.45
# Max Damage Test Episode 759 finished with total reward: 3.98
# Max Damage Test Episode 760 finished with total reward: 5.19
# Max Damage Test Episode 761 finished with total reward: 5.32
# Max Damage Test Episode 762 finished with total reward: 3.67
# Max Damage Test Episode 763 finished with total reward: 5.36
# Max Damage Test Episode 764 finished with total reward: 4.26
# Max Damage Test Episode 765 finished with total reward: 5.44
# Max Damage Test Episode 766 finished with total reward: 3.77
# Max Damage Test Episode 767 finished with total reward: 3.68
# Max Damage Test Episode 768 finished with total reward: 5.20
# Max Damage Test Episode 769 finished with total reward: 3.52
# Max Damage Test Episode 770 finished with total reward: 5.47
# Max Damage Test Episode 771 finished with total reward: 3.77
# Max Damage Test Episode 772 finished with total reward: 5.12
# Max Damage Test Episode 773 finished with total reward: 5.25
# Max Damage Test Episode 774 finished with total reward: 5.33
# Max Damage Test Episode 775 finished with total reward: 5.40
# Max Damage Test Episode 776 finished with total reward: 5.46
# Max Damage Test Episode 777 finished with total reward: 5.55
# Max Damage Test Episode 778 finished with total reward: 5.26
# Max Damage Test Episode 779 finished with total reward: 5.44
# Max Damage Test Episode 780 finished with total reward: 5.50
# Max Damage Test Episode 781 finished with total reward: 3.85
# Max Damage Test Episode 782 finished with total reward: 3.41
# Max Damage Test Episode 783 finished with total reward: 3.82
# Max Damage Test Episode 784 finished with total reward: 5.25
# Max Damage Test Episode 785 finished with total reward: 5.21
# Max Damage Test Episode 786 finished with total reward: 3.84
# Max Damage Test Episode 787 finished with total reward: 5.34
# Max Damage Test Episode 788 finished with total reward: 5.30
# Max Damage Test Episode 789 finished with total reward: 3.38
# Max Damage Test Episode 790 finished with total reward: 5.17
# Max Damage Test Episode 791 finished with total reward: 5.46
# Max Damage Test Episode 792 finished with total reward: 4.47
# Max Damage Test Episode 793 finished with total reward: 5.67
# Max Damage Test Episode 794 finished with total reward: 5.27
# Max Damage Test Episode 795 finished with total reward: 5.48
# Max Damage Test Episode 796 finished with total reward: 5.19
# Max Damage Test Episode 797 finished with total reward: 2.82
# Max Damage Test Episode 798 finished with total reward: 3.56
# Max Damage Test Episode 799 finished with total reward: 3.80
# Max Damage Test Episode 800 finished with total reward: 3.32
# Max Damage Test Episode 801 finished with total reward: 4.30
# Max Damage Test Episode 802 finished with total reward: 5.57
# Max Damage Test Episode 803 finished with total reward: 5.14
# Max Damage Test Episode 804 finished with total reward: 5.37
# Max Damage Test Episode 805 finished with total reward: 3.28
# Max Damage Test Episode 806 finished with total reward: 5.35
# Max Damage Test Episode 807 finished with total reward: 3.21
# Max Damage Test Episode 808 finished with total reward: 3.52
# Max Damage Test Episode 809 finished with total reward: 3.21
# Max Damage Test Episode 810 finished with total reward: 3.07
# Max Damage Test Episode 811 finished with total reward: 3.86
# Max Damage Test Episode 812 finished with total reward: 3.85
# Max Damage Test Episode 813 finished with total reward: 3.01
# Max Damage Test Episode 814 finished with total reward: 3.03
# Max Damage Test Episode 815 finished with total reward: 3.98
# Max Damage Test Episode 816 finished with total reward: 5.35
# Max Damage Test Episode 817 finished with total reward: 5.31
# Max Damage Test Episode 818 finished with total reward: 4.25
# Max Damage Test Episode 819 finished with total reward: 3.69
# Max Damage Test Episode 820 finished with total reward: 5.41
# Max Damage Test Episode 821 finished with total reward: 5.61
# Max Damage Test Episode 822 finished with total reward: 2.46
# Max Damage Test Episode 823 finished with total reward: 2.88
# Max Damage Test Episode 824 finished with total reward: 5.25
# Max Damage Test Episode 825 finished with total reward: 5.38
# Max Damage Test Episode 826 finished with total reward: 5.58
# Max Damage Test Episode 827 finished with total reward: 5.25
# Max Damage Test Episode 828 finished with total reward: 5.45
# Max Damage Test Episode 829 finished with total reward: 5.37
# Max Damage Test Episode 830 finished with total reward: 5.90
# Max Damage Test Episode 831 finished with total reward: 5.72
# Max Damage Test Episode 832 finished with total reward: 5.17
# Max Damage Test Episode 833 finished with total reward: 5.39
# Max Damage Test Episode 834 finished with total reward: 5.38
# Max Damage Test Episode 835 finished with total reward: 5.76
# Max Damage Test Episode 836 finished with total reward: 3.76
# Max Damage Test Episode 837 finished with total reward: 3.40
# Max Damage Test Episode 838 finished with total reward: 5.41
# Max Damage Test Episode 839 finished with total reward: 3.08
# Max Damage Test Episode 840 finished with total reward: 4.14
# Max Damage Test Episode 841 finished with total reward: 5.41
# Max Damage Test Episode 842 finished with total reward: 5.36
# Max Damage Test Episode 843 finished with total reward: 5.58
# Max Damage Test Episode 844 finished with total reward: 3.60
# Max Damage Test Episode 845 finished with total reward: 3.89
# Max Damage Test Episode 846 finished with total reward: 5.44
# Max Damage Test Episode 847 finished with total reward: 5.25
# Max Damage Test Episode 848 finished with total reward: 4.15
# Max Damage Test Episode 849 finished with total reward: 2.73
# Max Damage Test Episode 850 finished with total reward: 5.40
# Max Damage Test Episode 851 finished with total reward: 4.33
# Max Damage Test Episode 852 finished with total reward: 5.19
# Max Damage Test Episode 853 finished with total reward: 5.96
# Max Damage Test Episode 854 finished with total reward: 5.43
# Max Damage Test Episode 855 finished with total reward: 2.62
# Max Damage Test Episode 856 finished with total reward: 2.77
# Max Damage Test Episode 857 finished with total reward: 5.39
# Max Damage Test Episode 858 finished with total reward: 3.89
# Max Damage Test Episode 859 finished with total reward: 5.28
# Max Damage Test Episode 860 finished with total reward: 4.22
# Max Damage Test Episode 861 finished with total reward: 3.59
# Max Damage Test Episode 862 finished with total reward: 3.58
# Max Damage Test Episode 863 finished with total reward: 5.84
# Max Damage Test Episode 864 finished with total reward: 5.21
# Max Damage Test Episode 865 finished with total reward: 4.24
# Max Damage Test Episode 866 finished with total reward: 3.59
# Max Damage Test Episode 867 finished with total reward: 5.31
# Max Damage Test Episode 868 finished with total reward: 5.32
# Max Damage Test Episode 869 finished with total reward: 3.28
# Max Damage Test Episode 870 finished with total reward: 5.19
# Max Damage Test Episode 871 finished with total reward: 5.09
# Max Damage Test Episode 872 finished with total reward: 0.89
# Max Damage Test Episode 873 finished with total reward: 5.32
# Max Damage Test Episode 874 finished with total reward: 4.09
# Max Damage Test Episode 875 finished with total reward: 3.97
# Max Damage Test Episode 876 finished with total reward: 1.86
# Max Damage Test Episode 877 finished with total reward: 5.73
# Max Damage Test Episode 878 finished with total reward: 3.32
# Max Damage Test Episode 879 finished with total reward: 5.32
# Max Damage Test Episode 880 finished with total reward: 3.20
# Max Damage Test Episode 881 finished with total reward: 5.26
# Max Damage Test Episode 882 finished with total reward: 5.34
# Max Damage Test Episode 883 finished with total reward: 3.82
# Max Damage Test Episode 884 finished with total reward: 5.37
# Max Damage Test Episode 885 finished with total reward: 3.68
# Max Damage Test Episode 886 finished with total reward: 5.17
# Max Damage Test Episode 887 finished with total reward: 5.83
# Max Damage Test Episode 888 finished with total reward: 3.60
# Max Damage Test Episode 889 finished with total reward: 5.42
# Max Damage Test Episode 890 finished with total reward: 4.18
# Max Damage Test Episode 891 finished with total reward: 5.33
# Max Damage Test Episode 892 finished with total reward: 3.59
# Max Damage Test Episode 893 finished with total reward: 5.54
# Max Damage Test Episode 894 finished with total reward: 3.58
# Max Damage Test Episode 895 finished with total reward: 5.41
# Max Damage Test Episode 896 finished with total reward: 5.20
# Max Damage Test Episode 897 finished with total reward: 4.06
# Max Damage Test Episode 898 finished with total reward: 5.48
# Max Damage Test Episode 899 finished with total reward: 5.29
# Max Damage Test Episode 900 finished with total reward: 4.18
# Max Damage Test Episode 901 finished with total reward: 3.79
# Max Damage Test Episode 902 finished with total reward: 5.25
# Max Damage Test Episode 903 finished with total reward: 5.25
# Max Damage Test Episode 904 finished with total reward: 5.45
# Max Damage Test Episode 905 finished with total reward: 5.29
# Max Damage Test Episode 906 finished with total reward: 2.95
# Max Damage Test Episode 907 finished with total reward: 5.40
# Max Damage Test Episode 908 finished with total reward: 5.23
# Max Damage Test Episode 909 finished with total reward: 5.90
# Max Damage Test Episode 910 finished with total reward: 5.24
# Max Damage Test Episode 911 finished with total reward: 5.61
# Max Damage Test Episode 912 finished with total reward: 4.19
# Max Damage Test Episode 913 finished with total reward: 5.73
# Max Damage Test Episode 914 finished with total reward: 5.37
# Max Damage Test Episode 915 finished with total reward: 2.29
# Max Damage Test Episode 916 finished with total reward: 5.35
# Max Damage Test Episode 917 finished with total reward: 4.03
# Max Damage Test Episode 918 finished with total reward: 5.39
# Max Damage Test Episode 919 finished with total reward: 5.57
# Max Damage Test Episode 920 finished with total reward: 4.14
# Max Damage Test Episode 921 finished with total reward: 5.59
# Max Damage Test Episode 922 finished with total reward: 5.58
# Max Damage Test Episode 923 finished with total reward: 5.37
# Max Damage Test Episode 924 finished with total reward: 5.38
# Max Damage Test Episode 925 finished with total reward: 3.53
# Max Damage Test Episode 926 finished with total reward: 5.26
# Max Damage Test Episode 927 finished with total reward: 5.41
# Max Damage Test Episode 928 finished with total reward: 5.32
# Max Damage Test Episode 929 finished with total reward: 5.29
# Max Damage Test Episode 930 finished with total reward: 2.97
# Max Damage Test Episode 931 finished with total reward: 4.52
# Max Damage Test Episode 932 finished with total reward: 3.62
# Max Damage Test Episode 933 finished with total reward: 3.73
# Max Damage Test Episode 934 finished with total reward: 5.08
# Max Damage Test Episode 935 finished with total reward: 5.30
# Max Damage Test Episode 936 finished with total reward: 4.23
# Max Damage Test Episode 937 finished with total reward: 5.31
# Max Damage Test Episode 938 finished with total reward: 5.30
# Max Damage Test Episode 939 finished with total reward: 5.55
# Max Damage Test Episode 940 finished with total reward: 5.35
# Max Damage Test Episode 941 finished with total reward: 3.92
# Max Damage Test Episode 942 finished with total reward: 3.54
# Max Damage Test Episode 943 finished with total reward: 5.31
# Max Damage Test Episode 944 finished with total reward: 3.60
# Max Damage Test Episode 945 finished with total reward: 5.12
# Max Damage Test Episode 946 finished with total reward: 5.34
# Max Damage Test Episode 947 finished with total reward: 3.77
# Max Damage Test Episode 948 finished with total reward: 5.23
# Max Damage Test Episode 949 finished with total reward: 0.99
# Max Damage Test Episode 950 finished with total reward: 3.80
# Max Damage Test Episode 951 finished with total reward: 3.78
# Max Damage Test Episode 952 finished with total reward: 5.23
# Max Damage Test Episode 953 finished with total reward: 3.59
# Max Damage Test Episode 954 finished with total reward: 5.24
# Max Damage Test Episode 955 finished with total reward: 5.36
# Max Damage Test Episode 956 finished with total reward: 3.35
# Max Damage Test Episode 957 finished with total reward: 5.22
# Max Damage Test Episode 958 finished with total reward: 5.54
# Max Damage Test Episode 959 finished with total reward: 5.66
# Max Damage Test Episode 960 finished with total reward: 5.48
# Max Damage Test Episode 961 finished with total reward: 3.66
# Max Damage Test Episode 962 finished with total reward: 5.57
# Max Damage Test Episode 963 finished with total reward: 5.45
# Max Damage Test Episode 964 finished with total reward: 5.12
# Max Damage Test Episode 965 finished with total reward: 5.42
# Max Damage Test Episode 966 finished with total reward: 5.31
# Max Damage Test Episode 967 finished with total reward: 5.28
# Max Damage Test Episode 968 finished with total reward: 5.65
# Max Damage Test Episode 969 finished with total reward: 5.55
# Max Damage Test Episode 970 finished with total reward: 3.76
# Max Damage Test Episode 971 finished with total reward: 4.15
# Max Damage Test Episode 972 finished with total reward: 5.49
# Max Damage Test Episode 973 finished with total reward: 5.45
# Max Damage Test Episode 974 finished with total reward: 1.96
# Max Damage Test Episode 975 finished with total reward: 5.20
# Max Damage Test Episode 976 finished with total reward: 5.45
# Max Damage Test Episode 977 finished with total reward: 3.33
# Max Damage Test Episode 978 finished with total reward: 2.59
# Max Damage Test Episode 979 finished with total reward: 2.57
# Max Damage Test Episode 980 finished with total reward: 3.53
# Max Damage Test Episode 981 finished with total reward: 5.30
# Max Damage Test Episode 982 finished with total reward: 5.44
# Max Damage Test Episode 983 finished with total reward: 3.39
# Max Damage Test Episode 984 finished with total reward: 5.23
# Max Damage Test Episode 985 finished with total reward: 5.45
# Max Damage Test Episode 986 finished with total reward: 4.02
# Max Damage Test Episode 987 finished with total reward: 5.25
# Max Damage Test Episode 988 finished with total reward: 5.21
# Max Damage Test Episode 989 finished with total reward: 3.62
# Max Damage Test Episode 990 finished with total reward: 4.31
# Max Damage Test Episode 991 finished with total reward: 5.25
# Max Damage Test Episode 992 finished with total reward: 3.78
# Max Damage Test Episode 993 finished with total reward: 5.29
# Max Damage Test Episode 994 finished with total reward: 5.32
# Max Damage Test Episode 995 finished with total reward: 5.31
# Max Damage Test Episode 996 finished with total reward: 5.15
# Max Damage Test Episode 997 finished with total reward: 5.22
# Max Damage Test Episode 998 finished with total reward: 4.14
# Max Damage Test Episode 999 finished with total reward: 4.44
# Max Damage Test Episode 1000 finished with total reward: 5.73
# Win rate against max damage agent: 60.40%
# Average reward: 4.62
